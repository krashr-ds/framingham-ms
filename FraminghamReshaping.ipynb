# %% [markdown]
# ## Framingham Reshaping
#
# Turning the longitudinal Framingham data into a format suitable for multistate modeling.
#
# We will focus on creating a data set suitable for three states: No disease, Cardiovascular disease (any), and Death (absorbing).

# %%
# %matplotlib inline
import matplotlib
import pandas as pd
import numpy as np

# %%
framingham = pd.read_csv("Datasets/framingham.csv")

# %%
framingham
# Out:
#        SEX   RANDID TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE CIGPDAY    BMI  \
# 0        1     2448     195   39  106.0   70.0         0       0  26.97
# 1        1     2448     209   52  121.0   66.0         0       0      .
# 2        2     6238     250   46  121.0   81.0         0       0  28.73
# 3        2     6238     260   52  105.0   69.5         0       0  29.43
# 4        2     6238     237   58  108.0   66.0         0       0   28.5
# ...    ...      ...     ...  ...    ...    ...       ...     ...    ...
# 11622    1  9998212     173   46  126.0   82.0         0       0  19.17
# 11623    1  9998212     153   52  143.0   89.0         0       0  25.74
# 11624    2  9999312     196   39  133.0   86.0         1      30  20.91
# 11625    2  9999312     240   46  138.0   79.0         1      20  26.39
# 11626    2  9999312       .   50  147.0   96.0         1      10  24.19
#
#        DIABETES  ... CVD HYPERTEN TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0             0  ...   1        0   8766    6438      6438     6438      8766
# 1             0  ...   1        0   8766    6438      6438     6438      8766
# 2             0  ...   0        0   8766    8766      8766     8766      8766
# 3             0  ...   0        0   8766    8766      8766     8766      8766
# 4             0  ...   0        0   8766    8766      8766     8766      8766
# ...         ...  ...  ..      ...    ...     ...       ...      ...       ...
# 11622         0  ...   0        1   8766    8766      8766     8766      8766
# 11623         0  ...   0        1   8766    8766      8766     8766      8766
# 11624         0  ...   0        1   8766    8766      8766     8766      8766
# 11625         0  ...   0        1   8766    8766      8766     8766      8766
# 11626         0  ...   0        1   8766    8766      8766     8766      8766
#
#        TIMECVD  TIMEDTH  TIMEHYP
# 0         6438     8766     8766
# 1         6438     8766     8766
# 2         8766     8766     8766
# 3         8766     8766     8766
# 4         8766     8766     8766
# ...        ...      ...      ...
# 11622     8766     8766        0
# 11623     8766     8766        0
# 11624     8766     8766     4201
# 11625     8766     8766     4201
# 11626     8766     8766     4201
#
# [11627 rows x 38 columns]

# %%
framingham.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11627 entries, 0 to 11626
# Data columns (total 38 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEX       11627 non-null  int64
#  1   RANDID    11627 non-null  int64
#  2   TOTCHOL   11627 non-null  object
#  3   AGE       11627 non-null  int64
#  4   SYSBP     11627 non-null  float64
#  5   DIABP     11627 non-null  float64
#  6   CURSMOKE  11627 non-null  int64
#  7   CIGPDAY   11627 non-null  object
#  8   BMI       11627 non-null  object
#  9   DIABETES  11627 non-null  int64
#  10  BPMEDS    11627 non-null  object
#  11  HEARTRTE  11627 non-null  object
#  12  GLUCOSE   11627 non-null  object
#  13  PREVCHD   11627 non-null  int64
#  14  PREVAP    11627 non-null  int64
#  15  PREVMI    11627 non-null  int64
#  16  PREVSTRK  11627 non-null  int64
#  17  PREVHYP   11627 non-null  int64
#  18  TIME      11627 non-null  int64
#  19  PERIOD    11627 non-null  int64
#  20  HDLC      11627 non-null  object
#  21  LDLC      11627 non-null  object
#  22  DEATH     11627 non-null  int64
#  23  ANGINA    11627 non-null  int64
#  24  HOSPMI    11627 non-null  int64
#  25  MI_FCHD   11627 non-null  int64
#  26  ANYCHD    11627 non-null  int64
#  27  STROKE    11627 non-null  int64
#  28  CVD       11627 non-null  int64
#  29  HYPERTEN  11627 non-null  int64
#  30  TIMEAP    11627 non-null  int64
#  31  TIMEMI    11627 non-null  int64
#  32  TIMEMIFC  11627 non-null  int64
#  33  TIMECHD   11627 non-null  int64
#  34  TIMESTRK  11627 non-null  int64
#  35  TIMECVD   11627 non-null  int64
#  36  TIMEDTH   11627 non-null  int64
#  37  TIMEHYP   11627 non-null  int64
# dtypes: float64(2), int64(28), object(8)
# memory usage: 3.4+ MB

# %%
at_risk = framingham[(framingham["PREVAP"] == 0) & (framingham["PREVCHD"] == 0) & (framingham["PREVMI"] == 0) & (framingham["PREVSTRK"] == 0)] 
at_risk = at_risk[["RANDID", "TIME", "PERIOD", "TIMECVD", "TIMEDTH", "TIMEHYP", "PREVHYP", "AGE", "SEX", "BMI", "CURSMOKE", "DIABETES"]]
at_risk
# Out:
#         RANDID  TIME  PERIOD  TIMECVD  TIMEDTH  TIMEHYP  PREVHYP  AGE  SEX  \
# 0         2448     0       1     6438     8766     8766        0   39    1
# 1         2448  4628       3     6438     8766     8766        0   52    1
# 2         6238     0       1     8766     8766     8766        0   46    2
# 3         6238  2156       2     8766     8766     8766        0   52    2
# 4         6238  4344       3     8766     8766     8766        0   58    2
# ...        ...   ...     ...      ...      ...      ...      ...  ...  ...
# 11622  9998212  2333       2     8766     8766        0        1   46    1
# 11623  9998212  4538       3     8766     8766        0        1   52    1
# 11624  9999312     0       1     8766     8766     4201        0   39    2
# 11625  9999312  2390       2     8766     8766     4201        0   46    2
# 11626  9999312  4201       3     8766     8766     4201        1   50    2
#
#          BMI  CURSMOKE  DIABETES
# 0      26.97         0         0
# 1          .         0         0
# 2      28.73         0         0
# 3      29.43         0         0
# 4       28.5         0         0
# ...      ...       ...       ...
# 11622  19.17         0         0
# 11623  25.74         0         0
# 11624  20.91         1         0
# 11625  26.39         1         0
# 11626  24.19         1         0
#
# [10668 rows x 12 columns]

# %%
f = frm[frm.TIMEDTH == 8766]
f.groupby(["RANDID"]).mean()
# Out:
#                 TIME  PERIOD  TIMECVD  TIMEDTH  TIMEHYP   PREVHYP        AGE  \
# RANDID
# 2448     2314.000000     2.0   6438.0   8766.0   8766.0  0.000000  45.500000
# 6238     2166.666667     2.0   8766.0   8766.0   8766.0  0.000000  52.000000
# 9428     1099.500000     1.5   8766.0   8766.0   8766.0  0.000000  51.000000
# 11252    2119.000000     2.0   8766.0   8766.0   4285.0  0.333333  51.666667
# 11263    2176.333333     2.0   5719.0   8766.0      0.0  1.000000  49.000000
# ...              ...     ...      ...      ...      ...       ...        ...
# 9969773  2163.000000     2.0   7994.0   8766.0      0.0  1.000000  56.000000
# 9978986  2136.000000     2.0   8766.0   8766.0      0.0  1.000000  62.000000
# 9995546  1093.000000     1.5   5209.0   8766.0    735.0  0.500000  55.000000
# 9998212  2290.333333     2.0   8766.0   8766.0      0.0  1.000000  46.000000
# 9999312  2197.000000     2.0   8766.0   8766.0   4201.0  0.333333  45.000000
#
#          SEX  CURSMOKE  DIABETES
# RANDID
# 2448     1.0  0.000000  0.000000
# 6238     2.0  0.000000  0.000000
# 9428     1.0  1.000000  0.000000
# 11252    2.0  1.000000  0.000000
# 11263    2.0  0.000000  0.333333
# ...      ...       ...       ...
# 9969773  2.0  0.000000  1.000000
# 9978986  2.0  0.666667  0.000000
# 9995546  2.0  0.000000  0.000000
# 9998212  1.0  0.000000  0.000000
# 9999312  2.0  1.000000  0.000000
#
# [2884 rows x 10 columns]

# %%
f2 = frm[frm.TIMEDTH < 8766]
f2.groupby(["RANDID"]).mean()
# Out:
#                 TIME  PERIOD  TIMECVD  TIMEDTH  TIMEHYP   PREVHYP        AGE  \
# RANDID
# 10552     988.500000     1.5   2089.0   2956.0      0.0  1.000000  64.000000
# 23727    2263.333333     2.0   5592.0   5592.0      0.0  1.000000  47.000000
# 24721    2225.333333     2.0   6411.0   6411.0   4408.0  0.333333  45.333333
# 30928       0.000000     1.0    146.0    146.0      0.0  1.000000  38.000000
# 33555       0.000000     1.0   1442.0   1442.0   1442.0  0.000000  46.000000
# ...              ...     ...      ...      ...      ...       ...        ...
# 9983319     0.000000     1.0    565.0    565.0      0.0  1.000000  68.000000
# 9984683  1046.500000     1.5   1884.0   4300.0      0.0  1.000000  53.000000
# 9989287  2195.666667     2.0   7746.0   7746.0   7746.0  0.000000  57.000000
# 9990894  2212.000000     2.0   6433.0   6433.0   2219.0  0.666667  54.000000
# 9993179  2207.333333     2.0   6729.0   6729.0   4396.0  0.333333  50.000000
#
#          SEX  CURSMOKE  DIABETES
# RANDID
# 10552    2.0       1.0       0.0
# 23727    2.0       0.0       0.0
# 24721    2.0       1.0       0.0
# 30928    2.0       1.0       0.0
# 33555    2.0       1.0       0.0
# ...      ...       ...       ...
# 9983319  1.0       0.0       0.0
# 9984683  1.0       1.0       0.0
# 9989287  1.0       1.0       0.0
# 9990894  2.0       1.0       0.0
# 9993179  2.0       1.0       0.0
#
# [1550 rows x 10 columns]

# %%
f3 = frm[frm.TIMECVD == 8766 and frm.PREVCVD == 0]
f3.groupby(["RANDID"]).mean()
# Out:
#                 TIME  PERIOD  TIMECVD  TIMEDTH  TIMEHYP   PREVHYP        AGE  \
# RANDID
# 6238     2166.666667     2.0   8766.0   8766.0   8766.0  0.000000  52.000000
# 9428     1099.500000     1.5   8766.0   8766.0   8766.0  0.000000  51.000000
# 11252    2119.000000     2.0   8766.0   8766.0   4285.0  0.333333  51.666667
# 12629    1106.000000     1.5   8766.0   8766.0   2212.0  0.500000  66.500000
# 12806    2153.000000     2.0   8766.0   8766.0   8679.0  0.000000  51.000000
# ...              ...     ...      ...      ...      ...       ...        ...
# 9960803  1093.500000     1.5   8766.0   8766.0   8766.0  0.000000  50.000000
# 9961615  2296.333333     2.0   8766.0   8766.0   2205.0  0.666667  51.333333
# 9978986  2136.000000     2.0   8766.0   8766.0      0.0  1.000000  62.000000
# 9998212  2290.333333     2.0   8766.0   8766.0      0.0  1.000000  46.000000
# 9999312  2197.000000     2.0   8766.0   8766.0   4201.0  0.333333  45.000000
#
#          SEX  CURSMOKE  DIABETES
# RANDID
# 6238     2.0  0.000000  0.000000
# 9428     1.0  1.000000  0.000000
# 11252    2.0  1.000000  0.000000
# 12629    2.0  0.000000  0.000000
# 12806    2.0  1.000000  0.000000
# ...      ...       ...       ...
# 9960803  1.0  0.500000  0.000000
# 9961615  1.0  1.000000  0.333333
# 9978986  2.0  0.666667  0.000000
# 9998212  1.0  0.000000  0.000000
# 9999312  2.0  1.000000  0.000000
#
# [2461 rows x 10 columns]

# %%
f2.shape
# Out:
# (6950, 12)
